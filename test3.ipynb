# %%
import pandas as pd
from sklearn.cluster import KMeans

# %%
#1、读取数据文件并查看前10行数据和数据集的行列数。(2分)
df=pd.read_csv("../data/Students.csv")
df
# Out:
#       id  f1  f2  f3  f4  f5  f6  f7  f8  f9  ...  f22  f23  f24  f25  f26  \
# 0      1   2   2   3   3   1   2   2   1   1  ...    1    1    1    3    2
# 1      2   2   2   3   3   1   2   2   1   1  ...    1    1    1    3    2
# 2      3   2   2   2   3   2   2   2   2   4  ...    1    1    1    2    2
# 3      4   1   1   1   3   1   2   1   2   1  ...    1    1    2    3    2
# 4      5   2   2   1   3   2   2   1   3   1  ...    1    2    1    2    2
# ..   ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...
# 140  141   2   1   2   3   1   1   2   1   1  ...    1    1    1    2    1
# 141  142   1   1   2   4   2   2   2   1   4  ...    2    1    1    3    2
# 142  143   1   1   1   4   2   2   2   1   1  ...    1    1    1    3    3
# 143  144   2   1   2   4   1   1   1   5   2  ...    1    2    1    2    1
# 144  145   1   1   1   5   2   2   2   3   1  ...    1    2    1    3    2
#
#      f27  f28  f29  f30  COURSE ID
# ...

# %%
df.head(10)
# Out:
#    id  f1  f2  f3  f4  f5  f6  f7  f8  f9  ...  f22  f23  f24  f25  f26  f27  \
# 0   1   2   2   3   3   1   2   2   1   1  ...    1    1    1    3    2    1
# 1   2   2   2   3   3   1   2   2   1   1  ...    1    1    1    3    2    3
# 2   3   2   2   2   3   2   2   2   2   4  ...    1    1    1    2    2    1
# 3   4   1   1   1   3   1   2   1   2   1  ...    1    1    2    3    2    2
# 4   5   2   2   1   3   2   2   1   3   1  ...    1    2    1    2    2    2
# 5   6   2   2   2   3   2   2   2   2   1  ...    1    1    1    1    2    1
# 6   7   1   2   2   4   2   2   2   1   1  ...    2    1    1    3    3    3
# 7   8   1   1   2   3   1   1   1   2   2  ...    1    3    1    3    2    2
# 8   9   2   1   3   3   2   1   1   1   1  ...    1    1    1    3    2    2
# 9  10   2   1   2   3   2   2   1   3   4  ...    2    1    1    2    2    2
#
#    f28  f29  f30  COURSE ID
# 0    2    1    1          1
# 1    2    2    3          1
# 2    1    2    2          1
# ...

# %%
df.shape
# Out:
# (145, 32)

# %%
kmeans = KMeans(n_clusters=6,init='k-means++').fit(df)
kmeans
# Out:
# KMeans(n_clusters=6)

# %%
kmeans.cluster_centers_
# Out:
# array([[133.5       ,   1.20833333,   1.04166667,   1.79166667,
#           4.        ,   1.5       ,   1.29166667,   1.625     ,
#           1.625     ,   1.83333333,   2.04166667,   2.29166667,
#           2.33333333,   2.58333333,   1.16666667,   2.66666667,
#           2.875     ,   2.70833333,   1.83333333,   2.16666667,
#           1.625     ,   1.29166667,   1.08333333,   1.5       ,
#           1.20833333,   2.75      ,   2.04166667,   2.375     ,
#           1.125     ,   2.83333333,   2.70833333,   8.875     ],
#        [ 34.        ,   1.95652174,   1.86956522,   1.95652174,
#           3.26086957,   1.60869565,   1.7826087 ,   1.47826087,
#           1.60869565,   1.43478261,   1.43478261,   1.86956522,
#           2.56521739,   2.86956522,   1.08695652,   2.2173913 ,
#           2.95652174,   2.04347826,   1.95652174,   2.04347826,
#           1.        ,   1.        ,   1.34782609,   1.17391304,
#           1.04347826,   2.47826087,   1.7826087 ,   2.47826087,
# ...

# %%
kmeans.inertia_
# Out:
# 9726.06875696767
